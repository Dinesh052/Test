# %% [markdown]
# # Crisis Negotiator — Full Training & Evaluation Pipeline
# **Run on HF Spaces GPU (L4/A10G) — estimated cost: $2-4, time: 1-2 hours**

# %%
# Install dependencies
# !pip install -q openenv-core peft trl accelerate datasets bitsandbytes sentence-transformers torch transformers

# %%
# Clone repo
# !git clone -b kaggle_version https://github.com/Dinesh052/Test.git cn
# %cd cn

# %%
# Check GPU
import torch
print(f'GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "NO GPU"}')
print(f'VRAM: {torch.cuda.get_device_properties(0).total_mem / 1e9:.1f} GB' if torch.cuda.is_available() else '')

# %%
# Run EVERYTHING — training + all 5 eval tasks
# !python run_all.py 2>&1 | tee pipeline_output.log

# %%
# If you want a quick test first (10 min):
# !python run_all.py --quick

# %%
# Display results
import json
for f in ['eval_summary.json', 'belief_convergence_results.json', 'coevolution_log.json', 'exploit_analysis.json']:
    try:
        d = json.load(open(f'results/{f}'))
        print(f'\n=== {f} ===')
        print(json.dumps(d, indent=2)[:500])
    except: pass

# %%
# Display plots
from IPython.display import Image, display
for p in ['reward_curve.png', 'reward_curve_training_v2.png', 'belief_convergence.png', 'coevolution_curves.png']:
    try:
        display(Image(f'plots/{p}', width=600))
    except: pass

# %%
# Download all results
# !zip -r crisis_negotiator_results.zip results/ plots/ crisis-negotiator-trained-v2/ q_network.pt
from google.colab import files
files.download('crisis_negotiator_results.zip')
